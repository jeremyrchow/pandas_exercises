# %% [markdown]
# # Ex -

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep = '\t')

# %% [markdown]
# ### Step 4.

# %%
num_bowls_with_guac = \
    df[(df['item_name'].str.contains('Bowl')) &
   (df['choice_description'].str.contains('Guacamole'))].quantity.sum()

# %%
num_bows_overall = \
    df[(df['item_name'].str.contains('Bowl'))].quantity.sum()

# %% [markdown]
# ### Step 5.

# %%
num_bowls_with_guac/num_bows_overall
# Out:
# 0.4270386266094421

# %%
df.item_name.sort_values().unique()
# Out:
# array(['6 Pack Soft Drink', 'Barbacoa Bowl', 'Barbacoa Burrito',
#        'Barbacoa Crispy Tacos', 'Barbacoa Salad Bowl',
#        'Barbacoa Soft Tacos', 'Bottled Water', 'Bowl', 'Burrito',
#        'Canned Soda', 'Canned Soft Drink', 'Carnitas Bowl',
#        'Carnitas Burrito', 'Carnitas Crispy Tacos', 'Carnitas Salad',
#        'Carnitas Salad Bowl', 'Carnitas Soft Tacos', 'Chicken Bowl',
#        'Chicken Burrito', 'Chicken Crispy Tacos', 'Chicken Salad',
#        'Chicken Salad Bowl', 'Chicken Soft Tacos', 'Chips',
#        'Chips and Fresh Tomato Salsa', 'Chips and Guacamole',
#        'Chips and Mild Fresh Tomato Salsa',
#        'Chips and Roasted Chili Corn Salsa',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Tomatillo Green Chili Salsa',
#        'Chips and Tomatillo Red Chili Salsa',
#        'Chips and Tomatillo-Green Chili Salsa',
#        'Chips and Tomatillo-Red Chili Salsa', 'Crispy Tacos', 'Izze',
# ...

# %% [markdown]
# ### Step 6.

# %%
df[df.quantity > 1 ]
# Out:
#       order_id  quantity                              item_name                                                                                   choice_description  item_price  unit_price
# 4            2         2                           Chicken Bowl                           [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]       16.98        8.49
# 18           9         2                            Canned Soda                                                                                             [Sprite]        2.18        1.09
# 51          23         2                            Canned Soda                                                                                       [Mountain Dew]        2.18        1.09
# 135         60         2                     Chicken Salad Bowl                                       [Tomatillo Green Chili Salsa, [Sour Cream, Cheese, Guacamole]]       22.50       11.25
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep = '\t')

# %%
df.item_price = df.item_price.apply(lambda x: pd.to_numeric(x.strip()[1:]))

# %%
df['unit_price'] = df.item_price/df.quantity

# %%
chick_bowl_prices = df.loc[df.item_name == 'Chicken Bowl']['unit_price'].sort_values().unique()

# %%
pd.set_option('display.max_colwidth',100)

# %%
(df.choice_description.str.contains('Guacamole'))
# Out:
# 0         NaN
# 1       False
# 2       False
# 3         NaN
# 4       False
# 5        True
# 6         NaN
# 7        True
# 8       False
# 9       False
# 10        NaN
# 11      False
# 12      False
# 13       True
# 14        NaN
# 15        NaN
# 16      False
# 17      False
# 18      False
# 19      False
# 20        NaN
# 21      False
# 22      False
# 23       True
# 24      False
# 25        NaN
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4592     True
# 4593     True
# 4594     True
# 4595    False
# 4596      NaN
# 4597    False
# 4598      NaN
# 4599    False
# 4600      NaN
# 4601    False
# 4602    False
# 4603    False
# 4604    False
# 4605      NaN
# 4606    False
# 4607     True
# 4608     True
# 4609    False
# 4610     True
# 4611     True
# 4612    False
# 4613      NaN
# 4614      NaN
# 4615    False
# 4616      NaN
# 4617     True
# 4618     True
# 4619     True
# 4620    False
# 4621    False
# ...

# %%
# Price of chicken bowls with no extras
df.loc[(df.item_name == 'Chicken Bowl') &
       ~(df.choice_description.str.contains('Guacamole',na=True))]\
        .unit_price.sort_values().unique()
# Out:
# array([8.19, 8.49, 8.5 , 8.75])

# %%
df.groupby('item_name').quantity.sum().sort_values(ascending = False)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %%
df.loc[(df.item_name == 'Chips') | (df.item_name =='Side of Chips')].sum()
# Out:
# order_id                                                                                                           292773
# quantity                                                                                                              340
# item_name             Side of ChipsSide of ChipsChipsChipsSide of ChipsChipsChipsSide of ChipsChipsChipsChipsChipsSide...
# choice_description                                                                                                      0
# item_price                                                                                                         680.24
# unit_price                                                                                                         624.18
# dtype: object

# %% [markdown]
# ### Step 7.

# %%
df.groupby('item_name')['quantity','item_price'].sum().sort_values(by='item_price',ascending = False)
# Out:
#                                        quantity  item_price
# item_name
# Chicken Bowl                                761     7342.73
# Chicken Burrito                             591     5575.82
# Steak Burrito                               386     3851.43
# Steak Bowl                                  221     2260.19
# Chips and Guacamole                         506     2201.04
# Chicken Salad Bowl                          123     1228.75
# Chicken Soft Tacos                          120     1108.09
# Veggie Burrito                               97      934.77
# Barbacoa Burrito                             91      894.75
# Veggie Bowl                                  87      867.99
# Carnitas Bowl                                71      736.71
# Barbacoa Bowl                                66      672.36
# Carnitas Burrito                             60      597.83
# Steak Soft Tacos                             56      536.05
# ...

# %% [markdown]
# ### Step 8.

# %% [markdown]
# ### Step 9.

# %% [markdown]
# ### Step 10.

# %% [markdown]
# ### Step 11.

# %% [markdown]
# ### Step 12.

# %% [markdown]
# ### Step 13.

# %% [markdown]
# ### Step 14.

# %% [markdown]
# ### Step 15.

# %% [markdown]
# ### Step 16.

# %% [markdown]
# ### BONUS: Create your own question and answer it.
