# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data',
             sep='\s+', parse_dates=[['Yr','Mo','Dy']])
# '\s+' is regex for single OR multiple spaces to prevent skipping columns

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data['date'] = data['Yr_Mo_Dy']

# %%
data.drop(columns = ['Yr_Mo_Dy'],inplace = True)

# %%
data['date'][0].year
# Out:
# 2061

# %%
import datetime
def revert_100_years(x):
    
    if x.year > 2000:
        correct_year = x.year-100
        return datetime.date(correct_year, x.month, x.day)
    return x

# %%
data['date'] = data['date'].apply(revert_100_years)

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index('date',inplace = True)

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isna().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.notna().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats = data.describe(include='all')

# %%
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats=pd.DataFrame()
day_stats['min'] = data.min(axis=1)
day_stats['max'] = data.max(axis=1)
day_stats['mean'] = data.mean(axis = 1)
day_stats['stddev']=data.std(axis=1)
day_stats.head()
# Out:
#              min    max       mean    stddev
# date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data.loc[data.index.month==1].mean(axis=0)
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.resample('1Y').mean().head()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
#
#                   DUB        CLA       MUL        CLO        BEL        MAL
# date
# 1961-12-31   9.733923   8.858788  8.647652   9.835577  13.502795  13.680773
# 1962-12-31  11.020712   8.793753  8.316822   9.676247  12.930685  14.323956
# 1963-12-31  11.075699  10.336548  8.903589  10.224438  13.638877  14.999014
# 1964-12-31  10.259153   9.467350  7.789016  10.207951  13.740546  14.910301
# 1965-12-31  10.618712   8.879918  7.907425   9.918082  12.964247  15.591644

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
data.resample('1M').mean().head()
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
#
#                   DUB        CLA        MUL        CLO        BEL        MAL
# date
# 1961-01-31  11.184839   9.245333   9.085806  10.107419  13.880968  14.703226
# 1961-02-28  11.890714  11.846071  11.821429  12.714286  18.583214  15.411786
# 1961-03-31   9.644194   9.829677  10.294138  11.251935  16.410968  15.720000
# 1961-04-30   6.925333   7.094667   7.342333   7.237000  11.147333  10.278333
# 1961-05-31   7.604000   8.177097   8.039355   8.499355  11.900323  12.011613

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data.resample('1W').mean().head()
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
#
#                   DUB        CLA        MUL        CLO        BEL        MAL
# date
# 1961-01-01  13.670000  10.250000  10.830000  12.580000  18.500000  15.040000
# 1961-01-08  11.061429   6.616667   8.434286   8.497143  12.481429  13.238571
# 1961-01-15   7.535714   6.820000   5.712857   7.571429  11.125714  11.024286
# 1961-01-22   9.257143   7.875714   7.145714   8.124286   9.821429  11.434286
# 1961-01-29  15.528571  15.160000  14.480000  15.640000  20.930000  22.530000

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
df = pd.DataFrame()
df['means'] = data.resample('1W').mean().mean(axis=1)
df['min'] = data.resample('1W').mean().min(axis=1)
df['max'] = data.resample('1W').mean().max(axis=1)
df['stdev'] = data.resample('1W').mean().std(axis=1)

# %%
df
# Out:
#                 means        min        max     stdev
# date
# 1961-01-01  13.018182   9.290000  18.500000  2.808875
# 1961-01-08   9.847659   6.417143  13.541429  2.601705
# 1961-01-15   8.353214   4.630000  12.468571  2.719649
# 1961-01-22   9.368413   6.328571  13.204286  2.224531
# 1961-01-29  16.958095  12.720000  22.530000  2.915635
# 1961-02-05  11.800357   8.247143  16.827143  2.807310
# 1961-02-12  15.891548  10.774286  21.832857  3.147412
# 1961-02-19  13.726825   9.542857  21.167143  3.105819
# 1961-02-26  12.604286   8.524286  16.304286  2.364323
# 1961-03-05  11.766766   7.834286  17.842857  2.535336
# 1961-03-12  10.612579   6.881429  16.701429  2.746233
# 1961-03-19  11.756310   7.084286  19.350000  3.320318
# 1961-03-26  10.462857   6.648571  18.134286  3.071975
# 1961-04-02  10.268433   7.300000  13.900000  1.883742
# 1961-04-09   9.412381   5.958571  13.607143  2.399840
# 1961-04-16   6.845595   4.947143   9.482857  1.803831
# ...

# %%
df2=data.resample('1W').agg({'mean','min','max','std'})

# %%
df2.iloc[:52,:]
# Out:
#                   RPT                                VAL                \
#                  mean    min    max       std       mean    min    max
# date
# 1961-01-01  15.040000  15.04  15.04       NaN  14.960000  14.96  14.96
# 1961-01-08  13.541429  10.58  18.50  2.631321  11.486667   6.63  16.88
# 1961-01-15  12.468571   9.04  19.75  3.555392   8.967143   3.54  12.08
# 1961-01-22  13.204286   4.92  19.83  5.337402   9.862857   3.42  14.37
# 1961-01-29  19.880000  13.62  25.04  4.619061  16.141429   9.96  23.91
# 1961-02-05  16.827143  10.58  24.21  5.251408  15.460000   9.46  24.21
# 1961-02-12  19.684286  16.00  24.54  3.587677  16.417143  11.54  21.42
# 1961-02-19  15.130000   6.04  22.50  5.064609  15.091429  11.63  20.17
# 1961-02-26  15.221429   7.79  25.80  7.020716  13.625714   7.08  21.50
# 1961-03-05  12.101429  10.96  13.33  0.997721  12.951429   8.83  17.00
# 1961-03-12   9.376667   4.88  14.79  3.732263  11.578571   8.08  16.96
# ...
